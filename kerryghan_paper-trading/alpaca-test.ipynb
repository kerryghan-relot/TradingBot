# %%
from dotenv import load_dotenv
import os

load_dotenv()

print(os.getenv("ALPACA_API_KEY"))
# Out:
# PKS5RNOH2J36GJ7PVJIKDNZDYS

# %%
from datetime import datetime, timedelta
from alpaca.data.historical import StockHistoricalDataClient
from alpaca.data.requests import StockBarsRequest
from alpaca.data.timeframe import TimeFrame
import os

# Alpaca keys must be in environment variables (or load a .env first).
api_key = os.getenv("ALPACA_API_KEY")
secret_key = os.getenv("ALPACA_SECRET_KEY")

client = StockHistoricalDataClient(api_key, secret_key)

request_params = StockBarsRequest(
    symbol_or_symbols=["AAPL"],
    timeframe=TimeFrame.Day,
    start=datetime.utcnow() - timedelta(days=30),
    end=datetime.utcnow(),
)

bars = client.get_stock_bars(request_params)
df = bars.df
df.head()
# Out:
# C:\Users\Therryka\AppData\Local\Temp\ipykernel_23024\729427012.py:16: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   start=datetime.utcnow() - timedelta(days=30),
# C:\Users\Therryka\AppData\Local\Temp\ipykernel_23024\729427012.py:17: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   end=datetime.utcnow(),
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\Therryka\Documents\Personal Programming\TradingBot\TradingBot\.venv\Lib\site-packages\alpaca\common\rest.py:198, in RESTClient._one_request(self, method, url, opts, retry)
#     197 try:
# ...

# %%
from alpaca.data.historical import CryptoHistoricalDataClient
from alpaca.data.requests import CryptoBarsRequest
from alpaca.data.timeframe import TimeFrame

# no keys required for crypto data
client = CryptoHistoricalDataClient()

request_params = CryptoBarsRequest(
                        symbol_or_symbols=["BTC/USD", "ETH/USD"],
                        timeframe=TimeFrame.Day,
                        start="2022-07-01"
                 )

bars = client.get_crypto_bars(request_params)
bars.df
# Out:
#                                          open        high         low  \
# symbol  timestamp
# BTC/USD 2022-07-01 00:00:00+00:00  19935.5300  20896.3600  18940.0000
#         2022-07-02 00:00:00+00:00  19261.5800  19441.9000  18956.7900
#         2022-07-03 00:00:00+00:00  19227.6900  19625.3200  18752.9800
#         2022-07-04 00:00:00+00:00  19292.8800  20320.0000  19034.1300
#         2022-07-05 00:00:00+00:00  20212.6100  20728.5000  19281.3700
# ...                                       ...         ...         ...
# ETH/USD 2026-05-11 00:00:00+00:00   2372.3275   2373.5625   2304.1095
#         2026-05-12 00:00:00+00:00   2338.7650   2339.8350   2256.1705
#         2026-05-13 00:00:00+00:00   2275.1900   2322.5700   2233.4000
#         2026-05-14 00:00:00+00:00   2259.0420   2318.9650   2237.6650
#         2026-05-15 00:00:00+00:00   2283.5230   2299.3150   2282.1900
#
#                                         close       volume  trade_count  \
# symbol  timestamp
# ...

# %%
from alpaca.data.historical import StockHistoricalDataClient
from alpaca.data.requests import StockBarsRequest
from alpaca.data.timeframe import TimeFrame

# no keys required for stock data
api_key = os.getenv("ALPACA_API_KEY")
secret_key = os.getenv("ALPACA_SECRET_KEY")

client = StockHistoricalDataClient(api_key, secret_key)

SYMBOLS = ["AAPL", "GOOGL", "TSLA", "ABNB", "NVDA", "UBER", "SPOT", "META", "AMZN", "MSFT", "SHOP", "DIS", "NFLX", "COIN", "SNAP", "PYPL", "ROKU",
           "AMD"]

request_params = StockBarsRequest(
                        symbol_or_symbols=SYMBOLS,
                        timeframe=TimeFrame.Day,
                        start="2022-01-01"
                 )

bars = client.get_stock_bars(request_params)
print(len(SYMBOLS))
print(len(bars.df))

print(len(bars.df.index.get_level_values("symbol").unique()))
# Display unique symbols in the dataframe (symbols are the key in the multi-index)
print(bars.df.index.get_level_values("symbol").unique())
# Out:
# 17
# 18615
# 17
# Index(['COIN', 'DIS', 'GOOGL', 'META', 'MSFT', 'NVDA', 'AAPL', 'ABNB', 'AMZN',
#        'NFLX', 'TSLA', 'ROKU', 'SPOT', 'UBER', 'PYPL', 'SHOP', 'SNAP'],
#       dtype='str', name='symbol')

# %%
from pathlib import Path
Path(__file__).parent / "config.json"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 from pathlib import Path
# ----> 2 Path(__file__).parent / "config.json"
#
# NameError: name '__file__' is not defined

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("ALPACA_API_KEY")
secret_key = os.getenv("ALPACA_SECRET_KEY")

from alpaca.trading.client import TradingClient
from alpaca.trading.requests import MarketOrderRequest
from alpaca.trading.enums import OrderSide, TimeInForce

trading_client = TradingClient(api_key, secret_key)


# preparing order data
market_order_data = MarketOrderRequest(
                      symbol="BTC/USD",
                      qty=0.1,
                      side=OrderSide.BUY,
                      time_in_force=TimeInForce.GTC
                  )

# Market order
market_order = trading_client.submit_order(
                order_data=market_order_data
                )

# %%
SYMBOLS = set(["AAPL", "GOOGL", "TSLA", "ABNB", "NVDA", "UBER", "SPOT", "META", "AMZN", "MSFT", "SHOP", "DIS", "NFLX", "COIN", "SNAP", "PYPL", "ROKU",
           "AMD"])

WATCHLIST = set([
    # ── Technology ────────────────────────────────────────────────────────
    "AAPL",    # Apple
    "MSFT",    # Microsoft
    "NVDA",    # NVIDIA
    "AMD",     # Advanced Micro Devices
    "GOOGL",   # Alphabet
    "META",    # Meta
    "AMZN",    # Amazon
    "TSLA",    # Tesla
    "NFLX",    # Netflix
    "PLTR",    # Palantir

    # ── Consumer ──────────────────────────────────────────────────────────
    "DIS",     # Disney
    "UBER",    # Uber
    "ROKU",    # Roku
    "SNAP",    # Snap

    # ── Financials & Fintech ──────────────────────────────────────────────
    "JPM",     # JPMorgan Chase
    "GS",      # Goldman Sachs
    "BAC",     # Bank of America
    "MS",      # Morgan Stanley
    "PYPL",    # PayPal
    "SQ",      # Block (Square)

    # ── Healthcare ────────────────────────────────────────────────────────
    "UNH",     # UnitedHealth
    "ABBV",    # AbbVie
    "MRK",     # Merck

    # ── Energy ───────────────────────────────────────────────────────────
    "XOM",     # ExxonMobil
    "CVX",     # Chevron
    "COP",     # ConocoPhillips

    # ── ETFs ─────────────────────────────────────────────────────────────
    "SPY",     # S&P 500
    "QQQ",     # Nasdaq 100

    # ── Cryptocurrencies ─────────────────────────────────────────────────
    "BTC/USD", # Bitcoin
    "ETH/USD", # Ethereum
])

(SYMBOLS - WATCHLIST)
# Out:
# {'ABNB', 'COIN', 'SHOP', 'SPOT'}
